# %% [markdown]
# <a href="https://colab.research.google.com/github/celiolarcher/knowledge_repository/blob/main/evaluating_llm/FaQuAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Config

# %%
# !git clone https://github.com/celiolarcher/lm-evaluation-harness-PTBR.git
# Out:
# Cloning into 'lm-evaluation-harness-PTBR'...
# remote: Enumerating objects: 9217, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 9217 (delta 8), reused 16 (delta 6), pack-reused 9191
# Receiving objects: 100% (9217/9217), 12.33 MiB | 17.44 MiB/s, done.
# Resolving deltas: 100% (5891/5891), done.

# %%
# !pip install -e lm-evaluation-harness-PTBR
# Out:
# Obtaining file:///content/lm-evaluation-harness-PTBR
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for lm-eval
# ...

# %%
# !pip install SentencePiece accelerate bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 12.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import

# %%
import sys

sys.path.append('./lm-evaluation-harness-PTBR')

# %%
from lm_eval.evaluator import simple_evaluate

# %%
from huggingface_hub import login
login()

# %% [markdown]
# ## Run Task

# %%
result = simple_evaluate(
    model="hf-llama-causal",
    model_args="pretrained=openlm-research/open_llama_3b,low_cpu_mem_usage=True,dtype=float16",
    tasks=['faquad'],
    num_fewshot=4,
    batch_size=1,
    device="cuda:0",
    limit=None,
    bootstrap_iters=100000,
    description_dict={"faquad": "Forneça uma Resposta dado o Contexto."},
)
# Out:
# Using device 'cuda'
# Using device 'cuda:0'
# ...
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Token indices sequence length is longer than the specified maximum sequence length for this model (2067 > 2048). Running this sequence through the model will result in indexing errors
# Task: faquad; number of docs: 63
# Task: faquad; document 0; context prompt (starting on next line):
# Forneça uma Resposta dado o Contexto.
#
# ...

# %%
result
# Out:
# {'results': {'faquad': {'exact': 30.158730158730158,
#    'f1': 58.713314185949734,
#    'HasAns_exact': 30.158730158730158,
#    'HasAns_f1': 58.713314185949734,
#    'NoAns_exact': 0,
#    'NoAns_f1': 0,
#    'best_exact': 30.158730158730158,
#    'best_f1': 58.71331418594974}},
#  'versions': {'faquad': 1},
#  'config': {'model': 'hf-llama-causal',
#   'model_args': 'pretrained=openlm-research/open_llama_3b,low_cpu_mem_usage=True,dtype=float16',
#   'num_fewshot': 4,
#   'batch_size': 1,
#   'batch_sizes': [],
#   'device': 'cuda:0',
#   'no_cache': False,
#   'limit': None,
#   'bootstrap_iters': 100000,
#   'description_dict': {'faquad': 'Forneça uma Resposta dado o Contexto.'}}}
